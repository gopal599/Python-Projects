# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Gym = pd.read_csv(r"C:\Users\Shaik Sakhlaih\Downloads\powerlifting_dataset.csv")
Gym
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# ...              ...  ...          ...          ...                 ...
# 2995        John Doe   46        74 kg  Bench Press                 246
# 2996      Daniel Lee   39         Open     Deadlift                 244
# 2997    Sarah Thomas   62         Open        Squat                 148
# 2998     Chris Brown   32        93 kg  Bench Press                 333
# 2999      Daniel Lee   22        83 kg     Deadlift                 280
#
# [3000 rows x 5 columns]

# %%
Gym.head()
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235
# 3     Emily Davis   33        66 kg        Squat                 359
# 4    Laura Taylor   56        74 kg     Deadlift                 221

# %%
Gym.tail()
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2995      John Doe   46        74 kg  Bench Press                 246
# 2996    Daniel Lee   39         Open     Deadlift                 244
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
# Information of the data

Gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lifter Name         3000 non-null   object
#  1   Age                 3000 non-null   int64
#  2   Weight Class        3000 non-null   object
#  3   Lift Type           3000 non-null   object
#  4   Amount Lifted (kg)  3000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 117.3+ KB

# %%
# Finding the stastical and numerical information

Gym.describe()
# Out:
#                Age  Amount Lifted (kg)
# count  3000.000000         3000.000000
# mean     41.064000          250.332667
# std      13.682628           86.281208
# min      18.000000          100.000000
# 25%      29.000000          176.750000
# 50%      41.000000          250.000000
# 75%      53.000000          325.250000
# max      64.000000          399.000000

# %%
# Finding the rows and columns in the data

Gym.shape
# Out:
# (3000, 5)

# %%
Gym.sum()
# Out:
# Lifter Name           Jessica WilsonJohn DoeEmily DavisEmily DavisLa...
# Age                                                              123192
# Weight Class          59 kg83 kg105 kg66 kg74 kg74 kg83 kg120 kg93 k...
# Lift Type             Bench PressBench PressBench PressSquatDeadlift...
# Amount Lifted (kg)                                               750998
# dtype: object

# %%
# Figuring the particular row

Gym[Gym.index == 1 ]
# Out:
#   Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1    John Doe   60        83 kg  Bench Press                 179

# %%
# finding the null values in the data

Gym.isnull()
# Out:
#       Lifter Name    Age  Weight Class  Lift Type  Amount Lifted (kg)
# 0           False  False         False      False               False
# 1           False  False         False      False               False
# 2           False  False         False      False               False
# 3           False  False         False      False               False
# 4           False  False         False      False               False
# ...           ...    ...           ...        ...                 ...
# 2995        False  False         False      False               False
# 2996        False  False         False      False               False
# 2997        False  False         False      False               False
# 2998        False  False         False      False               False
# 2999        False  False         False      False               False
#
# [3000 rows x 5 columns]

# %%
# finding the null values by using sum - method

Gym.isnull().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
# Figiring out the column names 

a = Gym.columns

b = list[Gym.columns]

print(a)

print("------------------------------------------")

b
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')
# ------------------------------------------
# list[Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')]

# %%
# Findinig the top 5 largest vlaues in the 'Age' in the entire data

Gym.nlargest(5, 'Age')
# Out:
#           Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 12   Matthew Anderson   64        74 kg  Bench Press                 398
# 29           John Doe   64       105 kg        Squat                 263
# 88           John Doe   64        93 kg  Bench Press                 265
# 181        Daniel Lee   64        52 kg  Bench Press                 308
# 286  Matthew Anderson   64        52 kg  Bench Press                 318

# %%
# Finding the least 2 smallest values in 'Age' in the entire data

Gym.nsmallest(2, 'Age')
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 102  Michael Johnson   18        66 kg     Deadlift                 206
# 109     Laura Taylor   18        66 kg  Bench Press                 128

# %%
# Counting the values in the particular col which we want

Gym['Age'].value_counts().head()
# Out:
# Age
# 51    82
# 18    78
# 42    76
# 56    76
# 40    75
# Name: count, dtype: int64

# %%
Gym[['Age', 'Weight Class']].value_counts().tail()
# Out:
# Age  Weight Class
# 34   Open            2
# 54   74 kg           2
# 43   74 kg           2
# 32   83 kg           1
# 64   66 kg           1
# Name: count, dtype: int64

# %%
Gym[['Age', 'Weight Class']].head(10)
# Out:
#    Age Weight Class
# 0   46        59 kg
# 1   60        83 kg
# 2   41       105 kg
# 3   33        66 kg
# 4   56        74 kg
# 5   56        74 kg
# 6   40        83 kg
# 7   25       120 kg
# 8   55        93 kg
# 9   20        66 kg

# %%
# Finding the particular range of the data

Gym[Gym.index.isin(range(1,11))]
# Out:
#         Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1          John Doe   60        83 kg  Bench Press                 179
# 2       Emily Davis   41       105 kg  Bench Press                 235
# 3       Emily Davis   33        66 kg        Squat                 359
# 4      Laura Taylor   56        74 kg     Deadlift                 221
# 5      Sarah Thomas   56        74 kg        Squat                 264
# 6       Emily Davis   40        83 kg     Deadlift                 132
# 7    Jessica Wilson   25       120 kg  Bench Press                 178
# 8   Michael Johnson   55        93 kg        Squat                 265
# 9       Chris Brown   20        66 kg  Bench Press                 239
# 10     Laura Taylor   31        52 kg     Deadlift                 328

# %%
# Finding the mean value of the data

Gym.head(10)
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0   Jessica Wilson   46        59 kg  Bench Press                 269
# 1         John Doe   60        83 kg  Bench Press                 179
# 2      Emily Davis   41       105 kg  Bench Press                 235
# 3      Emily Davis   33        66 kg        Squat                 359
# 4     Laura Taylor   56        74 kg     Deadlift                 221
# 5     Sarah Thomas   56        74 kg        Squat                 264
# 6      Emily Davis   40        83 kg     Deadlift                 132
# 7   Jessica Wilson   25       120 kg  Bench Press                 178
# 8  Michael Johnson   55        93 kg        Squat                 265
# 9      Chris Brown   20        66 kg  Bench Press                 239

# %%
Gym.isnull().sum().head(10)
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
mean = Gym['Age'].mean()
mean
# Out:
# 41.064

# %%
# Filling the mean value in the place of null-values by using the - fillna()

Gym.fillna(mean).head(10)
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0   Jessica Wilson   46        59 kg  Bench Press                 269
# 1         John Doe   60        83 kg  Bench Press                 179
# 2      Emily Davis   41       105 kg  Bench Press                 235
# 3      Emily Davis   33        66 kg        Squat                 359
# 4     Laura Taylor   56        74 kg     Deadlift                 221
# 5     Sarah Thomas   56        74 kg        Squat                 264
# 6      Emily Davis   40        83 kg     Deadlift                 132
# 7   Jessica Wilson   25       120 kg  Bench Press                 178
# 8  Michael Johnson   55        93 kg        Squat                 265
# 9      Chris Brown   20        66 kg  Bench Press                 239

# %%
# Finding the median value of the data

Gym.tail(7)
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2993  Laura Taylor   42        66 kg        Squat                 187
# 2994  Sarah Thomas   62       105 kg  Bench Press                 191
# 2995      John Doe   46        74 kg  Bench Press                 246
# 2996    Daniel Lee   39         Open     Deadlift                 244
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
Gym.isnull().sum().tail(7)
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
median = Gym['Amount Lifted (kg)'].median()
median
# Out:
# 250.0

# %%
# Filling the median value in the place of null-values by using = fillna()

Gym.fillna(median).tail(7)
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2993  Laura Taylor   42        66 kg        Squat                 187
# 2994  Sarah Thomas   62       105 kg  Bench Press                 191
# 2995      John Doe   46        74 kg  Bench Press                 246
# 2996    Daniel Lee   39         Open     Deadlift                 244
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
# Finding the mode value of the data

Gym.head(8)
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235
# 3     Emily Davis   33        66 kg        Squat                 359
# 4    Laura Taylor   56        74 kg     Deadlift                 221
# 5    Sarah Thomas   56        74 kg        Squat                 264
# 6     Emily Davis   40        83 kg     Deadlift                 132
# 7  Jessica Wilson   25       120 kg  Bench Press                 178

# %%
Gym.isnull().sum().head(8)
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
mode = Gym['Age'].mode()
mode
# Out:
# 0    51
# Name: Age, dtype: int64

# %%
# Filling the mode value in the place of null-values by using = fillna()

Gym.fillna(mode).head(8)
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235
# 3     Emily Davis   33        66 kg        Squat                 359
# 4    Laura Taylor   56        74 kg     Deadlift                 221
# 5    Sarah Thomas   56        74 kg        Squat                 264
# 6     Emily Davis   40        83 kg     Deadlift                 132
# 7  Jessica Wilson   25       120 kg  Bench Press                 178

# %% [markdown]
# # Data Visualiazation

# %%
# Showing the line plot

plt.plot(Gym['Age'], Gym['Weight Class'], marker = 'D', color = 'skyblue', ms = 8, mec = 'black', linestyle = '--', lw = 0.8)
plt.xlabel("Age", color = 'orange')
plt.ylabel("Weight Class", color = 'purple')
plt.title(" Age Vs Weight Class", color = 'red')
plt.show()

# %%
# Showing barplot()

#plt.figure(figsize = (10,8))
plt.bar(Gym['Age'], Gym['Lift Type'], width = 0.50, color = 'c', edgecolor = 'black' )
plt.xlabel("Age", color = 'brown')
plt.ylabel("Lift Type", color = 'teal')
plt.title('Comparision b/w Age and Lift Type', color = 'navy')
plt.show()

# %%
# Showing Histogram

plt.hist(Gym['Age'], bins = 35, width = 2, histtype = 'barstacked', color = 'black', edgecolor = 'c')
plt.xlabel("Age", color = 'olive')
plt.ylabel("Counts", color = 'brown')
plt.title("Continuous of the Age", color = 'maroon')
plt.show()

# %%
# Showing the scatterplot()

plt.scatter(Gym['Age'], Gym['Weight Class'], marker = 'D', c = 'indigo', s = 15, alpha = 0.50)
plt.xlabel("Age", color = 'gray')
plt.ylabel("Weight Class", color = 'navy')
plt.title("Ploting the points b/w Age and Weight Class", color = 'blue')
plt.colorbar()
plt.show()

# %%
# Showing Pie - Chart

plt.figure(figsize = (10,10))
sakku = Gym[['Age', 'Weight Class']].value_counts().head(8)
c = ['coral', 'crimson', 'indigo', 'lime', 'olive', 'teal', 'gray', 'skyblue', 'orange', 'navy']
plt.pie(sakku, labels = sakku.index, autopct ='%1.2f%%', shadow = True, colors = c)
plt.legend(title = "10 Pair's")
plt.show()

# %%
# Showing lineplot()

plt.figure(figsize = (8,7))
sns.lineplot(data = Gym, x = 'Age', y = 'Weight Class', hue = 'Lift Type', marker = 'D', mec = 'b', size = 10)
plt.xlabel("Age", color = 'r')
plt.ylabel("Weight Class", color = 'navy')
plt.title("Difference b/w Age and Weight Class", color = 'brown')
plt.show()

# %%
# Showing barplot()

#plt.figure(figsize = (8,7))
sns.barplot(data = Gym, x = 'Amount Lifted (kg)', y = 'Lift Type', color = 'pink', width = 0.4, capsize = 0.10, gap = 0.10)
plt.xlabel('Amount Lifted (kg)', color = 'maroon')
plt.ylabel('Lift Type', color = 'brown')
plt.title("Comparision b/w Amount Lifted (kg) and Lift Type", color = 'crimson')
plt.show()

# %%
# Showing Scatterplot()

sns.scatterplot(data = Gym, x = "Age", y = "Amount Lifted (kg)", marker = "D", color = 'teal', alpha = 0.50 )
plt.xlabel("Age", color = 'gray')
plt.ylabel("Amount Lifted (kg)", color = 'navy')
plt.title("Plotting the scattering points b/w Age and Amount Lifted (kg)", color = 'indigo')
plt.show()

# %%
# Showing histplot()

plt.figure(figsize = (8,7))
sns.set(style = 'whitegrid')
sns.histplot(data = Gym, x = 'Age', hue = 'Lift Type', bins = 15, kde = True)
plt.xlabel("Age", color = 'red')
plt.ylabel("Count", color = 'blue')
plt.title("Continuous Histogram of Age", color = 'green')
plt.show()

# %%
# Showing boxplot()

sns.boxplot(data = Gym, x = 'Lift Type', y = 'Amount Lifted (kg)', color = 'brown', width = 0.5, gap = 0.5,)
plt.xlabel('Lift Type', color = 'olive')
plt.ylabel('Amount Lifted (kg)', color = 'teal')
plt.grid(True)
plt.title("Comparinig Distribution b/w Lift Type and Amount Lifted (kg)", color = 'navy')
plt.show()

# %%
# Showing violinplot()

sns.violinplot(data = Gym,  x = 'Weight Class', y = 'Amount Lifted (kg)', color = 'gray', width = 1, cut = 5,  gridsize = 20)
plt.xlabel("Weight Class", color = 'teal')
plt.ylabel("Amount Lifted (kg)", color = 'maroon')
plt.title("Identifying the Density Information b/w Weight Class and Amount Lifted (kg)", color = 'coral') 
plt.show()

# %%
# Showing countplot()

sns.countplot(data = Gym, x = 'Lift Type', color = 'indigo', width = 0.5)
plt.xlabel("Lift Type", color = 'Maroon')
plt.ylabel("count", color = 'orange')
plt.title("Comparing Frequency in the Lift Type", color = 'Navy')
plt.show()

# %%
# Showing pairplot() -  1

sns.pairplot(Gym)
plt.show()

# %%
# Showing pairplot() -  2

sns.pairplot(Gym, hue = "Age")
plt.show()

# %%
# Showing heatmap()

sakku = Gym[['Age', 'Amount Lifted (kg)']].corr()
sns.heatmap(sakku, annot = True, cmap = 'plasma')
plt.show()
